# %%
# %cd /ai-adulteration-detection

# %% [markdown]
# # Normalization

# %%
import os
# !pip install pydub
from pydub import AudioSegment, effects

# %%
input_path = "recordings"
output_path = "normalized_recordings"

filenames = sorted([f for f in os.listdir(input_path) if f.endswith(".wav")]) 

for i, recording in enumerate(filenames):
  print(recording)
  rawsound = AudioSegment.from_wav(os.path.join(input_path, recording)) 
  normalizedsound = effects.normalize(rawsound) 
  normalizedsound.export(os.path.join(output_path, recording), format="wav")

# %% [markdown]
# Inspect attributes of recordings before and after normalization

# %%
input_path = "recordings"
filenames = sorted([f for f in os.listdir(input_path) if f.endswith(".wav")]) 

for i, recording in enumerate(filenames):
  print(recording)
  rawsound = AudioSegment.from_wav(os.path.join(input_path, recording)) 
  print("Number of bytes in sample", rawsound.sample_width) # Number of bytes in each sample
  print("Loudness", rawsound.rms) # A measure of loudness, average amplitude, NOT in db
  print("Highest amplitude", rawsound.max) 
  print("Highest possible amplitude", rawsound.max_possible_amplitude)
  print("----------")

# %%
output_path = "normalized_recordings"
filenames = sorted([f for f in os.listdir(output_path) if f.endswith(".wav")]) 

for i, recording in enumerate(filenames):
  print(recording)
  rawsound = AudioSegment.from_wav(os.path.join(output_path, recording)) 
  print("Number of bytes in sample", rawsound.sample_width) # Number of bytes in each sample
  print("Loudness", rawsound.rms) # A measure of loudness, average amplitude, NOT in db
  print("Highest amplitude", rawsound.max)
  print("Highest possible amplitude", rawsound.max_possible_amplitude)
  print("----------")

# %% [markdown]
# # Sound preprocessing - creating 2sec chunks

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
input_path = "normalized_recordings"
filenames = sorted([f for f in os.listdir(input_path) if f.endswith(".wav")]) 
for i, recording in enumerate(filenames):
  print(recording)

# %% [markdown]
# ### Some plotting functions

# %%
from scipy.io.wavfile import read

# read and plot recordings by sample
def plot_part_of_audio(input_path):
  filenames = sorted([f for f in os.listdir(input_path) if f.endswith(".wav")])
  for f in filenames:
    sample_rate, recording = read(os.path.join(input_path, f))   
    # length = recording.shape[0]/sample_rate
    # print(f"Length of this file = {length} s")
    plt.plot(recording[88200:132300:])
    plt.xlabel("Sample")
    plt.ylabel("Amplitude")
    plt.title(f[:-4] + "\nSample Rate:" + str(sample_rate))
    plt.show()

# %%
# plot_part_of_audio(input_path)

# %%
from scipy.io.wavfile import read

# read and plot recordings by time
def plot_audio(input_path):
  filenames = sorted([f for f in os.listdir(input_path) if f.endswith(".wav")])
  for f in filenames:
    sample_rate, recording = read(os.path.join(input_path, f))
    length = recording.shape[0]/sample_rate
    print(f"Length of this file = {length} s")
    time = np.linspace(0, length, recording.shape[0])
    plt.plot(time, recording)    
    plt.xlabel("Time [s]")
    plt.ylabel("Amplitude")
    plt.title(f[:-4] + "\nSample Rate:" + str(sample_rate))
    plt.show()

# %%
# plot_audio(input_path)

# %% [markdown]
# ### Create 2-second chunks

# %%
# !pip install pydub
from pydub import AudioSegment
from pydub.utils import make_chunks
import random
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.6/dist-packages (0.24.1)

# %%
output_path = "sliding_chunks"
chunk_length_ms = 2000  # pydub calculates in millisec

o_b, n_b, c, e = 0, 0, 0, 0
all_c = 0

tot_number_of_chunks = 0

for f in filenames:
  recording = AudioSegment.from_wav(os.path.join(input_path, f))
  for s in range(10):
    recording = recording[2000+(200*s):-2000] # cuts 2 seconds from beginning and end 
    number_of_chunks = math.floor(recording.duration_seconds/2)
    tot_number_of_chunks += number_of_chunks
    chunks = make_chunks(recording, chunk_length_ms) 

    #Export all of the individual chunks as wav files
    for i, chunk in enumerate(chunks):
      if chunk.duration_seconds == chunk_length_ms/1000: # if it is exactly 2 seconds
        if ("Cheese1" in f) or ("Cheese2" in f) or ("Cheese3" in f):
          r = random.random()
          all_c += 1
          if r <= (1/3):
            label = "Cheese"
            chunk_name = "{0}_{1}.wav".format(label, c)
            c += 1
            
            print("exporting", chunk_name)
            chunk.export(os.path.join(output_path, chunk_name), format="wav")

        else:
          if "OrganicButter" in f:
            label = "OrganicButter"
            chunk_name = "{0}_{1}.wav".format(label, o_b)
            o_b += 1
          elif "NonorganicButter" in f: 
            label = "NonorganicButter"
            chunk_name = "{0}_{1}.wav".format(label, n_b)
            n_b += 1
          elif ("Cheese1" in f) or ("Cheese2" in f) or ("Cheese3" in f):
            label = "Cheese"
            chunk_name = "{0}_{1}.wav".format(label, c)
            c += 1
          elif "Empty" in f:
            label = "Empty"
            chunk_name = "{0}_{1}.wav".format(label, e)
            e += 1
          
          # print("exporting", chunk_name)
          chunk.export(os.path.join(output_path, chunk_name), format="wav") 

print("Exporting finished. Total number of chunks is {0}".format(o_b + n_b + c + e))
# Out:
# exporting Cheese_0.wav
# exporting Cheese_1.wav
# exporting Cheese_2.wav
# exporting Cheese_3.wav
# exporting Cheese_4.wav
# exporting Cheese_5.wav
# exporting Cheese_6.wav
# exporting Cheese_7.wav
# exporting Cheese_8.wav
# exporting Cheese_9.wav
# exporting Cheese_10.wav
# exporting Cheese_11.wav
# exporting Cheese_12.wav
# exporting Cheese_13.wav
# exporting Cheese_14.wav
# exporting Cheese_15.wav
# exporting Cheese_16.wav
# exporting Cheese_17.wav
# exporting Cheese_18.wav
# exporting Cheese_19.wav
# exporting Cheese_20.wav
# exporting Cheese_21.wav
# exporting Cheese_22.wav
# exporting Cheese_23.wav
# exporting Cheese_24.wav
# exporting Cheese_25.wav
# exporting Cheese_26.wav
# exporting Cheese_27.wav
# exporting Cheese_28.wav
# exporting Cheese_29.wav
# exporting Cheese_30.wav
# exporting Cheese_31.wav
# exporting Cheese_32.wav
# exporting Cheese_33.wav
# exporting Cheese_34.wav
# exporting Cheese_35.wav
# exporting Cheese_36.wav
# exporting Cheese_37.wav
# exporting Cheese_38.wav
# exporting Cheese_39.wav
# exporting Cheese_40.wav
# exporting Cheese_41.wav
# exporting Cheese_42.wav
# exporting Cheese_43.wav
# exporting Cheese_44.wav
# exporting Cheese_45.wav
# exporting Cheese_46.wav
# exporting Cheese_47.wav
# exporting Cheese_48.wav
# exporting Cheese_49.wav
# exporting Cheese_50.wav
# exporting Cheese_51.wav
# exporting Cheese_52.wav
# exporting Cheese_53.wav
# exporting Cheese_54.wav
# exporting Cheese_55.wav
# exporting Cheese_56.wav
# exporting Cheese_57.wav
# exporting Cheese_58.wav
# exporting Cheese_59.wav
# exporting Cheese_60.wav
# exporting Cheese_61.wav
# exporting Cheese_62.wav
# exporting Cheese_63.wav
# exporting Cheese_64.wav
# exporting Cheese_65.wav
# exporting Cheese_66.wav
# exporting Cheese_67.wav
# exporting Cheese_68.wav
# exporting Cheese_69.wav
# exporting Cheese_70.wav
# exporting Cheese_71.wav
# exporting Cheese_72.wav
# exporting Cheese_73.wav
# exporting Cheese_74.wav
# exporting Cheese_75.wav
# exporting Cheese_76.wav
# exporting Cheese_77.wav
# exporting Cheese_78.wav
# exporting Cheese_79.wav
# exporting Cheese_80.wav
# exporting Cheese_81.wav
# exporting Cheese_82.wav
# exporting Cheese_83.wav
# exporting Cheese_84.wav
# exporting Cheese_85.wav
# exporting Cheese_86.wav
# exporting Cheese_87.wav
# exporting Cheese_88.wav
# exporting Cheese_89.wav
# exporting Cheese_90.wav
# exporting Cheese_91.wav
# exporting Cheese_92.wav
# exporting Cheese_93.wav
# exporting Cheese_94.wav
# exporting Cheese_95.wav
# exporting Cheese_96.wav
# exporting Cheese_97.wav
# exporting Cheese_98.wav
# exporting Cheese_99.wav
# exporting Cheese_100.wav
# exporting Cheese_101.wav
# exporting Cheese_102.wav
# exporting Cheese_103.wav
# exporting Cheese_104.wav
# exporting Cheese_105.wav
# exporting Cheese_106.wav
# exporting Cheese_107.wav
# exporting Cheese_108.wav
# exporting Cheese_109.wav
# exporting Cheese_110.wav
# exporting Cheese_111.wav
# exporting Cheese_112.wav
# exporting Cheese_113.wav
# exporting Cheese_114.wav
# exporting Cheese_115.wav
# exporting Cheese_116.wav
# exporting Cheese_117.wav
# exporting Cheese_118.wav
# exporting Cheese_119.wav
# exporting Cheese_120.wav
# exporting Cheese_121.wav
# exporting Cheese_122.wav
# exporting Cheese_123.wav
# exporting Cheese_124.wav
# exporting Cheese_125.wav
# exporting Cheese_126.wav
# exporting Cheese_127.wav
# exporting Cheese_128.wav
# exporting Cheese_129.wav
# exporting Cheese_130.wav
# exporting Cheese_131.wav
# exporting Cheese_132.wav
# exporting Cheese_133.wav
# exporting Cheese_134.wav
# exporting Cheese_135.wav
# exporting Cheese_136.wav
# exporting Cheese_137.wav
# exporting Cheese_138.wav
# exporting Cheese_139.wav
# exporting Cheese_140.wav
# exporting Cheese_141.wav
# exporting Cheese_142.wav
# exporting Cheese_143.wav
# exporting Cheese_144.wav
# exporting Cheese_145.wav
# exporting Cheese_146.wav
# exporting Cheese_147.wav
# exporting Cheese_148.wav
# exporting Cheese_149.wav
# exporting Cheese_150.wav
# exporting Cheese_151.wav
# exporting Cheese_152.wav
# exporting Cheese_153.wav
# exporting Cheese_154.wav
# exporting Cheese_155.wav
# exporting Cheese_156.wav
# exporting Cheese_157.wav
# exporting Cheese_158.wav
# exporting Cheese_159.wav
# exporting Cheese_160.wav
# exporting Cheese_161.wav
# exporting Cheese_162.wav
# exporting Cheese_163.wav
# exporting Cheese_164.wav
# exporting Cheese_165.wav
# exporting Cheese_166.wav
# exporting Cheese_167.wav
# exporting Cheese_168.wav
# exporting Cheese_169.wav
# exporting Cheese_170.wav
# exporting Cheese_171.wav
# exporting Cheese_172.wav
# exporting Cheese_173.wav
# exporting Cheese_174.wav
# exporting Cheese_175.wav
# exporting Cheese_176.wav
# exporting Cheese_177.wav
# exporting Cheese_178.wav
# exporting Cheese_179.wav
# exporting Cheese_180.wav
# exporting Cheese_181.wav
# exporting Cheese_182.wav
# exporting Cheese_183.wav
# exporting Cheese_184.wav
# exporting Cheese_185.wav
# exporting Cheese_186.wav
# exporting Cheese_187.wav
# exporting Cheese_188.wav
# exporting Cheese_189.wav
# exporting Cheese_190.wav
# exporting Cheese_191.wav
# exporting Cheese_192.wav
# exporting Cheese_193.wav
# exporting Cheese_194.wav
# exporting Cheese_195.wav
# exporting Cheese_196.wav
# exporting Cheese_197.wav
# exporting Cheese_198.wav
# exporting Cheese_199.wav
# exporting Cheese_200.wav
# exporting Cheese_201.wav
# exporting Cheese_202.wav
# exporting Cheese_203.wav
# exporting Cheese_204.wav
# exporting Cheese_205.wav
# exporting Cheese_206.wav
# exporting Cheese_207.wav
# exporting Cheese_208.wav
# exporting Cheese_209.wav
# exporting Cheese_210.wav
# exporting Cheese_211.wav
# exporting Cheese_212.wav
# exporting Cheese_213.wav
# exporting Cheese_214.wav
# exporting Cheese_215.wav
# exporting Cheese_216.wav
# exporting Cheese_217.wav
# exporting Cheese_218.wav
# exporting Cheese_219.wav
# exporting Cheese_220.wav
# exporting Cheese_221.wav
# exporting Cheese_222.wav
# exporting Cheese_223.wav
# exporting Cheese_224.wav
# exporting Cheese_225.wav
# exporting Cheese_226.wav
# exporting Cheese_227.wav
# exporting Cheese_228.wav
# exporting Cheese_229.wav
# exporting Cheese_230.wav
# exporting Cheese_231.wav
# exporting Cheese_232.wav
# exporting Cheese_233.wav
# exporting Cheese_234.wav
# exporting Cheese_235.wav
# exporting Cheese_236.wav
# exporting Cheese_237.wav
# exporting Cheese_238.wav
# exporting Cheese_239.wav
# exporting Cheese_240.wav
# exporting Cheese_241.wav
# exporting Cheese_242.wav
# exporting Cheese_243.wav
# exporting Cheese_244.wav
# exporting Cheese_245.wav
# exporting Cheese_246.wav
# exporting Cheese_247.wav
# exporting Cheese_248.wav
# exporting Cheese_249.wav
# exporting Cheese_250.wav
# exporting Cheese_251.wav
# exporting Cheese_252.wav
# exporting Cheese_253.wav
# exporting Cheese_254.wav
# exporting Cheese_255.wav
# exporting Cheese_256.wav
# exporting Cheese_257.wav
# exporting Cheese_258.wav
# exporting Cheese_259.wav
# exporting Cheese_260.wav
# exporting Cheese_261.wav
# exporting Cheese_262.wav
# exporting Cheese_263.wav
# exporting Cheese_264.wav
# exporting Cheese_265.wav
# exporting Cheese_266.wav
# exporting Cheese_267.wav
# exporting Cheese_268.wav
# exporting Cheese_269.wav
# exporting Cheese_270.wav
# exporting Cheese_271.wav
# exporting Cheese_272.wav
# exporting Cheese_273.wav
# exporting Cheese_274.wav
# exporting Cheese_275.wav
# exporting Cheese_276.wav
# exporting Cheese_277.wav
# exporting Cheese_278.wav
# exporting Cheese_279.wav
# exporting Cheese_280.wav
# exporting Cheese_281.wav
# exporting Cheese_282.wav
# exporting Cheese_283.wav
# exporting Cheese_284.wav
# exporting Cheese_285.wav
# exporting Cheese_286.wav
# exporting Cheese_287.wav
# exporting Cheese_288.wav
# exporting Cheese_289.wav
# exporting Cheese_290.wav
# exporting Cheese_291.wav
# exporting Cheese_292.wav
# exporting Cheese_293.wav
# exporting Cheese_294.wav
# exporting Cheese_295.wav
# exporting Cheese_296.wav
# exporting Cheese_297.wav
# exporting Cheese_298.wav
# exporting Cheese_299.wav
# exporting Cheese_300.wav
# exporting Cheese_301.wav
# exporting Cheese_302.wav
# exporting Cheese_303.wav
# exporting Cheese_304.wav
# exporting Cheese_305.wav
# exporting Cheese_306.wav
# exporting Cheese_307.wav
# exporting Cheese_308.wav
# exporting Cheese_309.wav
# exporting Cheese_310.wav
# exporting Cheese_311.wav
# exporting Cheese_312.wav
# exporting Cheese_313.wav
# exporting Cheese_314.wav
# exporting Cheese_315.wav
# exporting Cheese_316.wav
# exporting Cheese_317.wav
# exporting Cheese_318.wav
# exporting Cheese_319.wav
# exporting Cheese_320.wav
# exporting Cheese_321.wav
# exporting Cheese_322.wav
# exporting Cheese_323.wav
# exporting Cheese_324.wav
# exporting Cheese_325.wav
# exporting Cheese_326.wav
# exporting Cheese_327.wav
# exporting Cheese_328.wav
# exporting Cheese_329.wav
# exporting Cheese_330.wav
# exporting Cheese_331.wav
# exporting Cheese_332.wav
# exporting Cheese_333.wav
# exporting Cheese_334.wav
# exporting Cheese_335.wav
# exporting Cheese_336.wav
# exporting Cheese_337.wav
# exporting Cheese_338.wav
# exporting Cheese_339.wav
# exporting Cheese_340.wav
# exporting Cheese_341.wav
# exporting Cheese_342.wav
# exporting Cheese_343.wav
# exporting Cheese_344.wav
# exporting Cheese_345.wav
# exporting Cheese_346.wav
# exporting Cheese_347.wav
# exporting Cheese_348.wav
# exporting Cheese_349.wav
# exporting Cheese_350.wav
# exporting Cheese_351.wav
# exporting Cheese_352.wav
# exporting Cheese_353.wav
# exporting Cheese_354.wav
# exporting Cheese_355.wav
# exporting Cheese_356.wav
# exporting Cheese_357.wav
# exporting Cheese_358.wav
# exporting Cheese_359.wav
# exporting Cheese_360.wav
# exporting Cheese_361.wav
# exporting Cheese_362.wav
# exporting Cheese_363.wav
# exporting Cheese_364.wav
# exporting Cheese_365.wav
# exporting Cheese_366.wav
# exporting Cheese_367.wav
# exporting Cheese_368.wav
# exporting Cheese_369.wav
# exporting Cheese_370.wav
# exporting Cheese_371.wav
# exporting Cheese_372.wav
# exporting Cheese_373.wav
# exporting Cheese_374.wav
# exporting Cheese_375.wav
# exporting Cheese_376.wav
# exporting Cheese_377.wav
# exporting Cheese_378.wav
# exporting Cheese_379.wav
# exporting Cheese_380.wav
# exporting Cheese_381.wav
# exporting Cheese_382.wav
# exporting Cheese_383.wav
# exporting Cheese_384.wav
# exporting Cheese_385.wav
# exporting Cheese_386.wav
# exporting Cheese_387.wav
# exporting Cheese_388.wav
# exporting Cheese_389.wav
# exporting Cheese_390.wav
# exporting Cheese_391.wav
# exporting Cheese_392.wav
# exporting Cheese_393.wav
# exporting Cheese_394.wav
# exporting Cheese_395.wav
# exporting Cheese_396.wav
# exporting Cheese_397.wav
# exporting Cheese_398.wav
# exporting Cheese_399.wav
# exporting Cheese_400.wav
# exporting Cheese_401.wav
# exporting Cheese_402.wav
# exporting Cheese_403.wav
# exporting Cheese_404.wav
# exporting Cheese_405.wav
# exporting Cheese_406.wav
# exporting Cheese_407.wav
# exporting Cheese_408.wav
# exporting Cheese_409.wav
# exporting Cheese_410.wav
# exporting Cheese_411.wav
# exporting Cheese_412.wav
# exporting Cheese_413.wav
# exporting Cheese_414.wav
# exporting Cheese_415.wav
# exporting Cheese_416.wav
# exporting Cheese_417.wav
# exporting Cheese_418.wav
# exporting Cheese_419.wav
# exporting Cheese_420.wav
# exporting Cheese_421.wav
# exporting Cheese_422.wav
# exporting Cheese_423.wav
# exporting Cheese_424.wav
# exporting Cheese_425.wav
# exporting Cheese_426.wav
# exporting Cheese_427.wav
# exporting Cheese_428.wav
# exporting Cheese_429.wav
# exporting Cheese_430.wav
# exporting Cheese_431.wav
# exporting Cheese_432.wav
# exporting Cheese_433.wav
# exporting Cheese_434.wav
# exporting Cheese_435.wav
# exporting Cheese_436.wav
# exporting Cheese_437.wav
# exporting Cheese_438.wav
# exporting Cheese_439.wav
# exporting Cheese_440.wav
# exporting Cheese_441.wav
# exporting Cheese_442.wav
# exporting Cheese_443.wav
# exporting Cheese_444.wav
# exporting Cheese_445.wav
# exporting Cheese_446.wav
# exporting Cheese_447.wav
# exporting Cheese_448.wav
# exporting Cheese_449.wav
# exporting Cheese_450.wav
# exporting Cheese_451.wav
# exporting Cheese_452.wav
# exporting Cheese_453.wav
# exporting Cheese_454.wav
# exporting Cheese_455.wav
# exporting Cheese_456.wav
# exporting Cheese_457.wav
# exporting Cheese_458.wav
# exporting Cheese_459.wav
# exporting Cheese_460.wav
# exporting Cheese_461.wav
# exporting Cheese_462.wav
# exporting Cheese_463.wav
# exporting Cheese_464.wav
# exporting Cheese_465.wav
# exporting Cheese_466.wav
# exporting Cheese_467.wav
# exporting Cheese_468.wav
# exporting Cheese_469.wav
# exporting Cheese_470.wav
# exporting Cheese_471.wav
# exporting Cheese_472.wav
# exporting Cheese_473.wav
# exporting Cheese_474.wav
# exporting Cheese_475.wav
# exporting Cheese_476.wav
# exporting Cheese_477.wav
# exporting Cheese_478.wav
# exporting Cheese_479.wav
# exporting Cheese_480.wav
# exporting Cheese_481.wav
# exporting Cheese_482.wav
# exporting Cheese_483.wav
# exporting Cheese_484.wav
# exporting Cheese_485.wav
# exporting Cheese_486.wav
# exporting Cheese_487.wav
# exporting Cheese_488.wav
# exporting Cheese_489.wav
# exporting Cheese_490.wav
# exporting Cheese_491.wav
# exporting Cheese_492.wav
# exporting Cheese_493.wav
# exporting Cheese_494.wav
# exporting Cheese_495.wav
# exporting Cheese_496.wav
# exporting Cheese_497.wav
# exporting Cheese_498.wav
# exporting Cheese_499.wav
# exporting Cheese_500.wav
# exporting Cheese_501.wav
# exporting Cheese_502.wav
# exporting Cheese_503.wav
# exporting Cheese_504.wav
# exporting Cheese_505.wav
# exporting Cheese_506.wav
# exporting Cheese_507.wav
# exporting Cheese_508.wav
# exporting Cheese_509.wav
# exporting Cheese_510.wav
# exporting Cheese_511.wav
# exporting Cheese_512.wav
# exporting Cheese_513.wav
# exporting Cheese_514.wav
# exporting Cheese_515.wav
# exporting Cheese_516.wav
# exporting Cheese_517.wav
# exporting Cheese_518.wav
# exporting Cheese_519.wav
# exporting Cheese_520.wav
# exporting Cheese_521.wav
# exporting Cheese_522.wav
# exporting Cheese_523.wav
# exporting Cheese_524.wav
# exporting Cheese_525.wav
# exporting Cheese_526.wav
# exporting Cheese_527.wav
# exporting Cheese_528.wav
# exporting Cheese_529.wav
# exporting Cheese_530.wav
# exporting Cheese_531.wav
# exporting Cheese_532.wav
# exporting Cheese_533.wav
# exporting Cheese_534.wav
# exporting Cheese_535.wav
# exporting Cheese_536.wav
# exporting Cheese_537.wav
# exporting Cheese_538.wav
# exporting Cheese_539.wav
# exporting Cheese_540.wav
# exporting Cheese_541.wav
# exporting Cheese_542.wav
# exporting Cheese_543.wav
# exporting Cheese_544.wav
# exporting Cheese_545.wav
# exporting Cheese_546.wav
# exporting Cheese_547.wav
# exporting Cheese_548.wav
# exporting Cheese_549.wav
# exporting Cheese_550.wav
# exporting Cheese_551.wav
# exporting Cheese_552.wav
# exporting Cheese_553.wav
# exporting Cheese_554.wav
# exporting Cheese_555.wav
# exporting Cheese_556.wav
# exporting Cheese_557.wav
# exporting Cheese_558.wav
# exporting Cheese_559.wav
# exporting Cheese_560.wav
# exporting Cheese_561.wav
# exporting Cheese_562.wav
# exporting Cheese_563.wav
# exporting Cheese_564.wav
# exporting Cheese_565.wav
# exporting Cheese_566.wav
# exporting Cheese_567.wav
# exporting Cheese_568.wav
# exporting Cheese_569.wav
# exporting Cheese_570.wav
# exporting Cheese_571.wav
# exporting Cheese_572.wav
# exporting Cheese_573.wav
# exporting Cheese_574.wav
# exporting Cheese_575.wav
# exporting Cheese_576.wav
# exporting Cheese_577.wav
# exporting Cheese_578.wav
# exporting Cheese_579.wav
# exporting Cheese_580.wav
# exporting Cheese_581.wav
# exporting Cheese_582.wav
# exporting Cheese_583.wav
# exporting Cheese_584.wav
# exporting Cheese_585.wav
# exporting Cheese_586.wav
# exporting Cheese_587.wav
# exporting Cheese_588.wav
# exporting Cheese_589.wav
# exporting Cheese_590.wav
# exporting Cheese_591.wav
# exporting Cheese_592.wav
# exporting Cheese_593.wav
# exporting Cheese_594.wav
# exporting Cheese_595.wav
# exporting Cheese_596.wav
# exporting Cheese_597.wav
# exporting Cheese_598.wav
# exporting Cheese_599.wav
# exporting Cheese_600.wav
# exporting Cheese_601.wav
# exporting Cheese_602.wav
# exporting Cheese_603.wav
# exporting Cheese_604.wav
# exporting Cheese_605.wav
# exporting Cheese_606.wav
# exporting Cheese_607.wav
# exporting Cheese_608.wav
# exporting Cheese_609.wav
# exporting Cheese_610.wav
# exporting Cheese_611.wav
# exporting Cheese_612.wav
# exporting Cheese_613.wav
# exporting Cheese_614.wav
# exporting Cheese_615.wav
# exporting Cheese_616.wav
# exporting Cheese_617.wav
# exporting Cheese_618.wav
# exporting Cheese_619.wav
# exporting Cheese_620.wav
# exporting Cheese_621.wav
# exporting Cheese_622.wav
# exporting Cheese_623.wav
# exporting Cheese_624.wav
# exporting Cheese_625.wav
# exporting Cheese_626.wav
# exporting Cheese_627.wav
# exporting Cheese_628.wav
# exporting Cheese_629.wav
# exporting Cheese_630.wav
# exporting Cheese_631.wav
# exporting Cheese_632.wav
# exporting Cheese_633.wav
# exporting Cheese_634.wav
# exporting Cheese_635.wav
# exporting Cheese_636.wav
# exporting Cheese_637.wav
# exporting Cheese_638.wav
# exporting Cheese_639.wav
# exporting Cheese_640.wav
# exporting Cheese_641.wav
# exporting Cheese_642.wav
# exporting Cheese_643.wav
# exporting Cheese_644.wav
# exporting Cheese_645.wav
# exporting Cheese_646.wav
# exporting Cheese_647.wav
# exporting Cheese_648.wav
# exporting Cheese_649.wav
# exporting Cheese_650.wav
# exporting Cheese_651.wav
# exporting Cheese_652.wav
# exporting Cheese_653.wav
# exporting Cheese_654.wav
# exporting Cheese_655.wav
# exporting Cheese_656.wav
# exporting Cheese_657.wav
# exporting Cheese_658.wav
# exporting Cheese_659.wav
# exporting Cheese_660.wav
# exporting Cheese_661.wav
# exporting Cheese_662.wav
# exporting Cheese_663.wav
# exporting Cheese_664.wav
# exporting Cheese_665.wav
# exporting Cheese_666.wav
# exporting Cheese_667.wav
# exporting Cheese_668.wav
# exporting Cheese_669.wav
# exporting Cheese_670.wav
# exporting Cheese_671.wav
# exporting Cheese_672.wav
# exporting Cheese_673.wav
# exporting Cheese_674.wav
# exporting Cheese_675.wav
# exporting Cheese_676.wav
# exporting Cheese_677.wav
# exporting Cheese_678.wav
# exporting Cheese_679.wav
# exporting Cheese_680.wav
# exporting Cheese_681.wav
# exporting Cheese_682.wav
# exporting Cheese_683.wav
# exporting Cheese_684.wav
# exporting Cheese_685.wav
# exporting Cheese_686.wav
# exporting Cheese_687.wav
# exporting Cheese_688.wav
# exporting Cheese_689.wav
# exporting Cheese_690.wav
# exporting Cheese_691.wav
# exporting Cheese_692.wav
# exporting Cheese_693.wav
# exporting Cheese_694.wav
# exporting Cheese_695.wav
# exporting Cheese_696.wav
# exporting Cheese_697.wav
# exporting Cheese_698.wav
# exporting Cheese_699.wav
# exporting Cheese_700.wav
# exporting Cheese_701.wav
# exporting Cheese_702.wav
# exporting Cheese_703.wav
# exporting Cheese_704.wav
# exporting Cheese_705.wav
# exporting Cheese_706.wav
# exporting Cheese_707.wav
# exporting Cheese_708.wav
# exporting Cheese_709.wav
# exporting Cheese_710.wav
# exporting Cheese_711.wav
# exporting Cheese_712.wav
# exporting Cheese_713.wav
# exporting Cheese_714.wav
# exporting Cheese_715.wav
# exporting Cheese_716.wav
# exporting Cheese_717.wav
# exporting Cheese_718.wav
# exporting Cheese_719.wav
# exporting Cheese_720.wav
# exporting Cheese_721.wav
# exporting Cheese_722.wav
# exporting Cheese_723.wav
# exporting Cheese_724.wav
# exporting Cheese_725.wav
# exporting Cheese_726.wav
# exporting Cheese_727.wav
# exporting Cheese_728.wav
# exporting Cheese_729.wav
# exporting Cheese_730.wav
# exporting Cheese_731.wav
# exporting Cheese_732.wav
# exporting Cheese_733.wav
# exporting Cheese_734.wav
# exporting Cheese_735.wav
# exporting Cheese_736.wav
# exporting Cheese_737.wav
# exporting Cheese_738.wav
# exporting Cheese_739.wav
# exporting Cheese_740.wav
# exporting Cheese_741.wav
# exporting Cheese_742.wav
# exporting Cheese_743.wav
# exporting Cheese_744.wav
# exporting Cheese_745.wav
# exporting Cheese_746.wav
# exporting Cheese_747.wav
# exporting Cheese_748.wav
# exporting Cheese_749.wav
# exporting Cheese_750.wav
# exporting Cheese_751.wav
# exporting Cheese_752.wav
# exporting Cheese_753.wav
# exporting Cheese_754.wav
# exporting Cheese_755.wav
# exporting Cheese_756.wav
# exporting Cheese_757.wav
# exporting Cheese_758.wav
# exporting Cheese_759.wav
# exporting Cheese_760.wav
# exporting Cheese_761.wav
# exporting Cheese_762.wav
# exporting Cheese_763.wav
# exporting Cheese_764.wav
# exporting Cheese_765.wav
# exporting Cheese_766.wav
# exporting Cheese_767.wav
# exporting Cheese_768.wav
# exporting Cheese_769.wav
# exporting Cheese_770.wav
# exporting Cheese_771.wav
# exporting Cheese_772.wav
# exporting Cheese_773.wav
# exporting Cheese_774.wav
# exporting Cheese_775.wav
# exporting Cheese_776.wav
# exporting Cheese_777.wav
# exporting Cheese_778.wav
# exporting Cheese_779.wav
# exporting Cheese_780.wav
# exporting Cheese_781.wav
# exporting Cheese_782.wav
# exporting Cheese_783.wav
# exporting Cheese_784.wav
# exporting Cheese_785.wav
# exporting Cheese_786.wav
# exporting Cheese_787.wav
# exporting Cheese_788.wav
# exporting Cheese_789.wav
# exporting Cheese_790.wav
# exporting Cheese_791.wav
# exporting Cheese_792.wav
# exporting Cheese_793.wav
# exporting Cheese_794.wav
# exporting Cheese_795.wav
# exporting Cheese_796.wav
# exporting Cheese_797.wav
# exporting Cheese_798.wav
# exporting Cheese_799.wav
# exporting Cheese_800.wav
# exporting Cheese_801.wav
# exporting Cheese_802.wav
# exporting Cheese_803.wav
# exporting Cheese_804.wav
# exporting Cheese_805.wav
# exporting Cheese_806.wav
# exporting Cheese_807.wav
# exporting Cheese_808.wav
# exporting Cheese_809.wav
# exporting Cheese_810.wav
# exporting Cheese_811.wav
# exporting Cheese_812.wav
# exporting Cheese_813.wav
# exporting Cheese_814.wav
# exporting Cheese_815.wav
# exporting Cheese_816.wav
# exporting Cheese_817.wav
# exporting Cheese_818.wav
# exporting Cheese_819.wav
# exporting Cheese_820.wav
# exporting Cheese_821.wav
# exporting Cheese_822.wav
# exporting Cheese_823.wav
# exporting Cheese_824.wav
# exporting Cheese_825.wav
# exporting Cheese_826.wav
# exporting Cheese_827.wav
# exporting Cheese_828.wav
# exporting Cheese_829.wav
# exporting Cheese_830.wav
# exporting Cheese_831.wav
# exporting Cheese_832.wav
# exporting Cheese_833.wav
# exporting Cheese_834.wav
# exporting Cheese_835.wav
# exporting Cheese_836.wav
# exporting Cheese_837.wav
# exporting Cheese_838.wav
# exporting Cheese_839.wav
# exporting Cheese_840.wav
# exporting Cheese_841.wav
# exporting Cheese_842.wav
# exporting Cheese_843.wav
# exporting Cheese_844.wav
# exporting Cheese_845.wav
# exporting Cheese_846.wav
# exporting Cheese_847.wav
# exporting Cheese_848.wav
# exporting Cheese_849.wav
# exporting Cheese_850.wav
# exporting Cheese_851.wav
# exporting Cheese_852.wav
# exporting Cheese_853.wav
# exporting Cheese_854.wav
# exporting Cheese_855.wav
# exporting Cheese_856.wav
# exporting Cheese_857.wav
# exporting Cheese_858.wav
# exporting Cheese_859.wav
# exporting Cheese_860.wav
# exporting Cheese_861.wav
# exporting Cheese_862.wav
# exporting Cheese_863.wav
# exporting Cheese_864.wav
# exporting Cheese_865.wav
# exporting Cheese_866.wav
# exporting Cheese_867.wav
# exporting Cheese_868.wav
# exporting Cheese_869.wav
# exporting Cheese_870.wav
# exporting Cheese_871.wav
# exporting Cheese_872.wav
# exporting Cheese_873.wav
# exporting Cheese_874.wav
# exporting Cheese_875.wav
# exporting Cheese_876.wav
# exporting Cheese_877.wav
# exporting Cheese_878.wav
# exporting Cheese_879.wav
# exporting Cheese_880.wav
# exporting Cheese_881.wav
# exporting Cheese_882.wav
# exporting Cheese_883.wav
# exporting Cheese_884.wav
# exporting Cheese_885.wav
# exporting Cheese_886.wav
# exporting Cheese_887.wav
# exporting Cheese_888.wav
# exporting Cheese_889.wav
# exporting Cheese_890.wav
# exporting Cheese_891.wav
# exporting Cheese_892.wav
# exporting Cheese_893.wav
# exporting Cheese_894.wav
# exporting Cheese_895.wav
# exporting Cheese_896.wav
# exporting Cheese_897.wav
# exporting Cheese_898.wav
# exporting Cheese_899.wav
# exporting Cheese_900.wav
# exporting Cheese_901.wav
# exporting Cheese_902.wav
# exporting Cheese_903.wav
# exporting Cheese_904.wav
# exporting Cheese_905.wav
# exporting Cheese_906.wav
# exporting Cheese_907.wav
# exporting Cheese_908.wav
# exporting Cheese_909.wav
# exporting Cheese_910.wav
# exporting Cheese_911.wav
# exporting Cheese_912.wav
# exporting Cheese_913.wav
# exporting Cheese_914.wav
# exporting Cheese_915.wav
# exporting Cheese_916.wav
# exporting Cheese_917.wav
# exporting Cheese_918.wav
# exporting Cheese_919.wav
# exporting Cheese_920.wav
# exporting Cheese_921.wav
# exporting Cheese_922.wav
# exporting Cheese_923.wav
# exporting Cheese_924.wav
# exporting Cheese_925.wav
# exporting Cheese_926.wav
# exporting Cheese_927.wav
# exporting Cheese_928.wav
# exporting Cheese_929.wav
# exporting Cheese_930.wav
# exporting Cheese_931.wav
# exporting Cheese_932.wav
# exporting Cheese_933.wav
# exporting Cheese_934.wav
# exporting Cheese_935.wav
# exporting Cheese_936.wav
# exporting Cheese_937.wav
# exporting Cheese_938.wav
# exporting Cheese_939.wav
# exporting Cheese_940.wav
# exporting Cheese_941.wav
# exporting Cheese_942.wav
# exporting Cheese_943.wav
# exporting Cheese_944.wav
# exporting Cheese_945.wav
# exporting Cheese_946.wav
# exporting Cheese_947.wav
# exporting Cheese_948.wav
# exporting Cheese_949.wav
# exporting Cheese_950.wav
# exporting Cheese_951.wav
# exporting Cheese_952.wav
# exporting Cheese_953.wav
# exporting Cheese_954.wav
# exporting Cheese_955.wav
# exporting Cheese_956.wav
# exporting Cheese_957.wav
# exporting Cheese_958.wav
# exporting Cheese_959.wav
# exporting Cheese_960.wav
# exporting Cheese_961.wav
# exporting Cheese_962.wav
# exporting Cheese_963.wav
# exporting Cheese_964.wav
# exporting Cheese_965.wav
# exporting Cheese_966.wav
# exporting Cheese_967.wav
# exporting Cheese_968.wav
# exporting Cheese_969.wav
# exporting Cheese_970.wav
# exporting Cheese_971.wav
# exporting Cheese_972.wav
# exporting Cheese_973.wav
# exporting Cheese_974.wav
# exporting Cheese_975.wav
# exporting Cheese_976.wav
# exporting Cheese_977.wav
# exporting Cheese_978.wav
# exporting Cheese_979.wav
# exporting Cheese_980.wav
# exporting Cheese_981.wav
# exporting Cheese_982.wav
# exporting Cheese_983.wav
# exporting Cheese_984.wav
# exporting Cheese_985.wav
# exporting Cheese_986.wav
# exporting Cheese_987.wav
# exporting Cheese_988.wav
# exporting Cheese_989.wav
# exporting Cheese_990.wav
# exporting Cheese_991.wav
# exporting Cheese_992.wav
# exporting Cheese_993.wav
# exporting Cheese_994.wav
# exporting Cheese_995.wav
# exporting Cheese_996.wav
# exporting Cheese_997.wav
# exporting Cheese_998.wav
# exporting Cheese_999.wav
# exporting Cheese_1000.wav
# exporting Cheese_1001.wav
# exporting Cheese_1002.wav
# exporting Cheese_1003.wav
# exporting Cheese_1004.wav
# exporting Cheese_1005.wav
# exporting Cheese_1006.wav
# exporting Cheese_1007.wav
# exporting Cheese_1008.wav
# exporting Cheese_1009.wav
# exporting Cheese_1010.wav
# exporting Cheese_1011.wav
# exporting Cheese_1012.wav
# exporting Cheese_1013.wav
# exporting Cheese_1014.wav
# exporting Cheese_1015.wav
# exporting Cheese_1016.wav
# exporting Cheese_1017.wav
# exporting Cheese_1018.wav
# exporting Cheese_1019.wav
# exporting Cheese_1020.wav
# exporting Cheese_1021.wav
# exporting Cheese_1022.wav
# exporting Cheese_1023.wav
# exporting Cheese_1024.wav
# exporting Cheese_1025.wav
# exporting Cheese_1026.wav
# exporting Cheese_1027.wav
# exporting Cheese_1028.wav
# exporting Cheese_1029.wav
# exporting Cheese_1030.wav
# exporting Cheese_1031.wav
# exporting Cheese_1032.wav
# exporting Cheese_1033.wav
# exporting Cheese_1034.wav
# exporting Cheese_1035.wav
# exporting Cheese_1036.wav
# exporting Cheese_1037.wav
# exporting Cheese_1038.wav
# exporting Cheese_1039.wav
# exporting Cheese_1040.wav
# exporting Cheese_1041.wav
# exporting Cheese_1042.wav
# exporting Cheese_1043.wav
# exporting Cheese_1044.wav
# exporting Cheese_1045.wav
# exporting Cheese_1046.wav
# exporting Cheese_1047.wav
# exporting Cheese_1048.wav
# exporting Cheese_1049.wav
# exporting Cheese_1050.wav
# exporting Cheese_1051.wav
# exporting Cheese_1052.wav
# exporting Cheese_1053.wav
# exporting Cheese_1054.wav
# exporting Cheese_1055.wav
# exporting Cheese_1056.wav
# exporting Cheese_1057.wav
# exporting Cheese_1058.wav
# exporting Cheese_1059.wav
# exporting Cheese_1060.wav
# exporting Cheese_1061.wav
# exporting Cheese_1062.wav
# exporting Cheese_1063.wav
# exporting Cheese_1064.wav
# exporting Cheese_1065.wav
# exporting Cheese_1066.wav
# exporting Cheese_1067.wav
# exporting Cheese_1068.wav
# exporting Cheese_1069.wav
# exporting Cheese_1070.wav
# exporting Cheese_1071.wav
# exporting Cheese_1072.wav
# exporting Cheese_1073.wav
# exporting Cheese_1074.wav
# exporting Cheese_1075.wav
# exporting Cheese_1076.wav
# exporting Cheese_1077.wav
# exporting Cheese_1078.wav
# exporting Cheese_1079.wav
# exporting Cheese_1080.wav
# exporting Cheese_1081.wav
# exporting Cheese_1082.wav
# exporting Cheese_1083.wav
# exporting Cheese_1084.wav
# exporting Cheese_1085.wav
# exporting Cheese_1086.wav
# exporting Cheese_1087.wav
# exporting Cheese_1088.wav
# exporting Cheese_1089.wav
# exporting Cheese_1090.wav
# exporting Cheese_1091.wav
# exporting Cheese_1092.wav
# exporting Cheese_1093.wav
# exporting Cheese_1094.wav
# exporting Cheese_1095.wav
# exporting Cheese_1096.wav
# exporting Cheese_1097.wav
# exporting Cheese_1098.wav
# exporting Cheese_1099.wav
# exporting Cheese_1100.wav
# exporting Cheese_1101.wav
# exporting Cheese_1102.wav
# exporting Cheese_1103.wav
# exporting Cheese_1104.wav
# exporting Cheese_1105.wav
# exporting Cheese_1106.wav
# exporting Cheese_1107.wav
# exporting Cheese_1108.wav
# exporting Cheese_1109.wav
# exporting Cheese_1110.wav
# exporting Cheese_1111.wav
# exporting Cheese_1112.wav
# exporting Cheese_1113.wav
# exporting Cheese_1114.wav
# exporting Cheese_1115.wav
# exporting Cheese_1116.wav
# exporting Cheese_1117.wav
# exporting Cheese_1118.wav
# exporting Cheese_1119.wav
# exporting Cheese_1120.wav
# exporting Cheese_1121.wav
# exporting Cheese_1122.wav
# exporting Cheese_1123.wav
# exporting Cheese_1124.wav
# exporting Cheese_1125.wav
# exporting Cheese_1126.wav
# exporting Cheese_1127.wav
# exporting Cheese_1128.wav
# exporting Cheese_1129.wav
# exporting Cheese_1130.wav
# exporting Cheese_1131.wav
# exporting Cheese_1132.wav
# exporting Cheese_1133.wav
# exporting Cheese_1134.wav
# exporting Cheese_1135.wav
# exporting Cheese_1136.wav
# exporting Cheese_1137.wav
# exporting Cheese_1138.wav
# exporting Cheese_1139.wav
# exporting Cheese_1140.wav
# exporting Cheese_1141.wav
# exporting Cheese_1142.wav
# exporting Cheese_1143.wav
# exporting Cheese_1144.wav
# exporting Cheese_1145.wav
# exporting Cheese_1146.wav
# exporting Cheese_1147.wav
# exporting Cheese_1148.wav
# exporting Cheese_1149.wav
# exporting Cheese_1150.wav
# exporting Cheese_1151.wav
# exporting Cheese_1152.wav
# exporting Cheese_1153.wav
# exporting Cheese_1154.wav
# exporting Cheese_1155.wav
# exporting Cheese_1156.wav
# exporting Cheese_1157.wav
# exporting Cheese_1158.wav
# exporting Cheese_1159.wav
# exporting Cheese_1160.wav
# exporting Cheese_1161.wav
# exporting Cheese_1162.wav
# exporting Cheese_1163.wav
# exporting Cheese_1164.wav
# exporting Cheese_1165.wav
# exporting Cheese_1166.wav
# exporting Cheese_1167.wav
# exporting Cheese_1168.wav
# exporting Cheese_1169.wav
# exporting Cheese_1170.wav
# exporting Cheese_1171.wav
# exporting Cheese_1172.wav
# exporting Cheese_1173.wav
# exporting Cheese_1174.wav
# exporting Cheese_1175.wav
# exporting Cheese_1176.wav
# exporting Cheese_1177.wav
# exporting Cheese_1178.wav
# exporting Cheese_1179.wav
# exporting Cheese_1180.wav
# exporting Cheese_1181.wav
# exporting Cheese_1182.wav
# exporting Cheese_1183.wav
# exporting Cheese_1184.wav
# exporting Cheese_1185.wav
# exporting Cheese_1186.wav
# exporting Cheese_1187.wav
# exporting Cheese_1188.wav
# exporting Cheese_1189.wav
# exporting Cheese_1190.wav
# exporting Cheese_1191.wav
# exporting Cheese_1192.wav
# exporting Cheese_1193.wav
# exporting Cheese_1194.wav
# exporting Cheese_1195.wav
# exporting Cheese_1196.wav
# exporting Cheese_1197.wav
# exporting Cheese_1198.wav
# exporting Cheese_1199.wav
# exporting Cheese_1200.wav
# exporting Cheese_1201.wav
# exporting Cheese_1202.wav
# exporting Cheese_1203.wav
# exporting Cheese_1204.wav
# exporting Cheese_1205.wav
# exporting Cheese_1206.wav
# exporting Cheese_1207.wav
# exporting Cheese_1208.wav
# exporting Cheese_1209.wav
# exporting Cheese_1210.wav
# exporting Cheese_1211.wav
# exporting Cheese_1212.wav
# exporting Cheese_1213.wav
# exporting Cheese_1214.wav
# exporting Cheese_1215.wav
# exporting Cheese_1216.wav
# exporting Cheese_1217.wav
# exporting Cheese_1218.wav
# exporting Cheese_1219.wav
# exporting Cheese_1220.wav
# exporting Cheese_1221.wav
# exporting Cheese_1222.wav
# exporting Cheese_1223.wav
# exporting Cheese_1224.wav
# exporting Cheese_1225.wav
# exporting Cheese_1226.wav
# exporting Cheese_1227.wav
# exporting Cheese_1228.wav
# exporting Cheese_1229.wav
# exporting Cheese_1230.wav
# exporting Cheese_1231.wav
# exporting Cheese_1232.wav
# exporting Cheese_1233.wav
# exporting Cheese_1234.wav
# exporting Cheese_1235.wav
# exporting Cheese_1236.wav
# exporting Cheese_1237.wav
# exporting Cheese_1238.wav
# exporting Cheese_1239.wav
# exporting Cheese_1240.wav
# exporting Cheese_1241.wav
# exporting Cheese_1242.wav
# exporting Cheese_1243.wav
# exporting Cheese_1244.wav
# exporting Cheese_1245.wav
# exporting Cheese_1246.wav
# exporting Cheese_1247.wav
# exporting Cheese_1248.wav
# exporting Cheese_1249.wav
# exporting Cheese_1250.wav
# exporting Cheese_1251.wav
# exporting Cheese_1252.wav
# exporting Cheese_1253.wav
# exporting Cheese_1254.wav
# exporting Cheese_1255.wav
# exporting Cheese_1256.wav
# exporting Cheese_1257.wav
# exporting Cheese_1258.wav
# exporting Cheese_1259.wav
# exporting Cheese_1260.wav
# exporting Cheese_1261.wav
# exporting Cheese_1262.wav
# exporting Cheese_1263.wav
# exporting Cheese_1264.wav
# exporting Cheese_1265.wav
# exporting Cheese_1266.wav
# exporting Cheese_1267.wav
# exporting Cheese_1268.wav
# exporting Cheese_1269.wav
# exporting Cheese_1270.wav
# exporting Cheese_1271.wav
# exporting Cheese_1272.wav
# exporting Cheese_1273.wav
# exporting Cheese_1274.wav
# exporting Cheese_1275.wav
# exporting Cheese_1276.wav
# exporting Cheese_1277.wav
# exporting Cheese_1278.wav
# exporting Cheese_1279.wav
# exporting Cheese_1280.wav
# exporting Cheese_1281.wav
# exporting Cheese_1282.wav
# exporting Cheese_1283.wav
# exporting Cheese_1284.wav
# exporting Cheese_1285.wav
# exporting Cheese_1286.wav
# exporting Cheese_1287.wav
# exporting Cheese_1288.wav
# exporting Cheese_1289.wav
# exporting Cheese_1290.wav
# exporting Cheese_1291.wav
# exporting Cheese_1292.wav
# exporting Cheese_1293.wav
# exporting Cheese_1294.wav
# exporting Cheese_1295.wav
# exporting Cheese_1296.wav
# exporting Cheese_1297.wav
# exporting Cheese_1298.wav
# exporting Cheese_1299.wav
# exporting Cheese_1300.wav
# exporting Cheese_1301.wav
# exporting Cheese_1302.wav
# exporting Cheese_1303.wav
# exporting Cheese_1304.wav
# exporting Cheese_1305.wav
# exporting Cheese_1306.wav
# exporting Cheese_1307.wav
# exporting Cheese_1308.wav
# exporting Cheese_1309.wav
# exporting Cheese_1310.wav
# exporting Cheese_1311.wav
# exporting Cheese_1312.wav
# exporting Cheese_1313.wav
# exporting Cheese_1314.wav
# exporting Cheese_1315.wav
# exporting Cheese_1316.wav
# exporting Cheese_1317.wav
# exporting Cheese_1318.wav
# exporting Cheese_1319.wav
# exporting Cheese_1320.wav
# exporting Cheese_1321.wav
# exporting Cheese_1322.wav
# exporting Cheese_1323.wav
# exporting Cheese_1324.wav
# exporting Cheese_1325.wav
# exporting Cheese_1326.wav
# exporting Cheese_1327.wav
# exporting Cheese_1328.wav
# exporting Cheese_1329.wav
# exporting Cheese_1330.wav
# exporting Cheese_1331.wav
# exporting Cheese_1332.wav
# exporting Cheese_1333.wav
# exporting Cheese_1334.wav
# exporting Cheese_1335.wav
# exporting Cheese_1336.wav
# exporting Cheese_1337.wav
# exporting Cheese_1338.wav
# exporting Cheese_1339.wav
# exporting Cheese_1340.wav
# exporting Cheese_1341.wav
# exporting Cheese_1342.wav
# exporting Cheese_1343.wav
# exporting Cheese_1344.wav
# exporting Cheese_1345.wav
# exporting Cheese_1346.wav
# exporting Cheese_1347.wav
# exporting Cheese_1348.wav
# exporting Cheese_1349.wav
# exporting Cheese_1350.wav
# exporting Cheese_1351.wav
# exporting Cheese_1352.wav
# exporting Cheese_1353.wav
# exporting Cheese_1354.wav
# exporting Cheese_1355.wav
# exporting Cheese_1356.wav
# exporting Cheese_1357.wav
# exporting Cheese_1358.wav
# exporting Cheese_1359.wav
# exporting Cheese_1360.wav
# exporting Cheese_1361.wav
# exporting Cheese_1362.wav
# exporting Cheese_1363.wav
# exporting Cheese_1364.wav
# exporting Cheese_1365.wav
# exporting Cheese_1366.wav
# exporting Cheese_1367.wav
# exporting Cheese_1368.wav
# exporting Cheese_1369.wav
# exporting Cheese_1370.wav
# exporting Cheese_1371.wav
# exporting Cheese_1372.wav
# exporting Cheese_1373.wav
# exporting Cheese_1374.wav
# exporting Cheese_1375.wav
# exporting Cheese_1376.wav
# exporting Cheese_1377.wav
# exporting Cheese_1378.wav
# exporting Cheese_1379.wav
# exporting Cheese_1380.wav
# exporting Cheese_1381.wav
# exporting Cheese_1382.wav
# exporting Cheese_1383.wav
# exporting Cheese_1384.wav
# exporting Cheese_1385.wav
# exporting Cheese_1386.wav
# exporting Cheese_1387.wav
# exporting Cheese_1388.wav
# exporting Cheese_1389.wav
# exporting Cheese_1390.wav
# exporting Cheese_1391.wav
# exporting Cheese_1392.wav
# exporting Cheese_1393.wav
# exporting Cheese_1394.wav
# exporting Cheese_1395.wav
# exporting Cheese_1396.wav
# exporting Cheese_1397.wav
# exporting Cheese_1398.wav
# exporting Cheese_1399.wav
# exporting Cheese_1400.wav
# exporting Cheese_1401.wav
# exporting Cheese_1402.wav
# exporting Cheese_1403.wav
# exporting Cheese_1404.wav
# exporting Cheese_1405.wav
# exporting Cheese_1406.wav
# exporting Cheese_1407.wav
# exporting Cheese_1408.wav
# exporting Cheese_1409.wav
# exporting Cheese_1410.wav
# exporting Cheese_1411.wav
# exporting Cheese_1412.wav
# exporting Cheese_1413.wav
# exporting Cheese_1414.wav
# exporting Cheese_1415.wav
# exporting Cheese_1416.wav
# exporting Cheese_1417.wav
# exporting Cheese_1418.wav
# exporting Cheese_1419.wav
# exporting Cheese_1420.wav
# exporting Cheese_1421.wav
# exporting Cheese_1422.wav
# exporting Cheese_1423.wav
# exporting Cheese_1424.wav
# exporting Cheese_1425.wav
# exporting Cheese_1426.wav
# exporting Cheese_1427.wav
# exporting Cheese_1428.wav
# exporting Cheese_1429.wav
# exporting Cheese_1430.wav
# exporting Cheese_1431.wav
# exporting Cheese_1432.wav
# exporting Cheese_1433.wav
# exporting Cheese_1434.wav
# exporting Cheese_1435.wav
# exporting Cheese_1436.wav
# exporting Cheese_1437.wav
# exporting Cheese_1438.wav
# exporting Cheese_1439.wav
# exporting Cheese_1440.wav
# exporting Cheese_1441.wav
# exporting Cheese_1442.wav
# exporting Cheese_1443.wav
# exporting Cheese_1444.wav
# exporting Cheese_1445.wav
# exporting Cheese_1446.wav
# exporting Cheese_1447.wav
# exporting Cheese_1448.wav
# exporting Cheese_1449.wav
# exporting Cheese_1450.wav
# exporting Cheese_1451.wav
# exporting Cheese_1452.wav
# exporting Cheese_1453.wav
# exporting Cheese_1454.wav
# exporting Cheese_1455.wav
# exporting Cheese_1456.wav
# exporting Cheese_1457.wav
# exporting Cheese_1458.wav
# exporting Cheese_1459.wav
# exporting Cheese_1460.wav
# exporting Cheese_1461.wav
# exporting Cheese_1462.wav
# exporting Cheese_1463.wav
# exporting Cheese_1464.wav
# exporting Cheese_1465.wav
# exporting Cheese_1466.wav
# exporting Cheese_1467.wav
# exporting Cheese_1468.wav
# exporting Cheese_1469.wav
# exporting Cheese_1470.wav
# exporting Cheese_1471.wav
# exporting Cheese_1472.wav
# exporting Cheese_1473.wav
# exporting Cheese_1474.wav
# exporting Cheese_1475.wav
# exporting Cheese_1476.wav
# exporting Cheese_1477.wav
# exporting Cheese_1478.wav
# exporting Cheese_1479.wav
# exporting Cheese_1480.wav
# exporting Cheese_1481.wav
# exporting Cheese_1482.wav
# exporting Cheese_1483.wav
# exporting Cheese_1484.wav
# exporting Cheese_1485.wav
# exporting Cheese_1486.wav
# exporting Cheese_1487.wav
# exporting Cheese_1488.wav
# exporting Cheese_1489.wav
# exporting Cheese_1490.wav
# exporting Cheese_1491.wav
# exporting Cheese_1492.wav
# exporting Cheese_1493.wav
# exporting Cheese_1494.wav
# exporting Cheese_1495.wav
# exporting Cheese_1496.wav
# exporting Cheese_1497.wav
# exporting Cheese_1498.wav
# exporting Cheese_1499.wav
# exporting Cheese_1500.wav
# exporting Cheese_1501.wav
# exporting Cheese_1502.wav
# exporting Cheese_1503.wav
# exporting Cheese_1504.wav
# exporting Cheese_1505.wav
# exporting Cheese_1506.wav
# exporting Cheese_1507.wav
# exporting Cheese_1508.wav
# exporting Cheese_1509.wav
# exporting Cheese_1510.wav
# exporting Cheese_1511.wav
# exporting Cheese_1512.wav
# exporting Cheese_1513.wav
# exporting Cheese_1514.wav
# exporting Cheese_1515.wav
# exporting Cheese_1516.wav
# exporting Cheese_1517.wav
# exporting Cheese_1518.wav
# exporting Cheese_1519.wav
# exporting Cheese_1520.wav
# exporting Cheese_1521.wav
# exporting Cheese_1522.wav
# exporting Cheese_1523.wav
# exporting Cheese_1524.wav
# exporting Cheese_1525.wav
# exporting Cheese_1526.wav
# exporting Cheese_1527.wav
# exporting Cheese_1528.wav
# exporting Cheese_1529.wav
# exporting Cheese_1530.wav
# exporting Cheese_1531.wav
# exporting Cheese_1532.wav
# exporting Cheese_1533.wav
# exporting Cheese_1534.wav
# exporting Cheese_1535.wav
# exporting Cheese_1536.wav
# exporting Cheese_1537.wav
# exporting Cheese_1538.wav
# exporting Cheese_1539.wav
# exporting Cheese_1540.wav
# exporting Cheese_1541.wav
# exporting Cheese_1542.wav
# exporting Cheese_1543.wav
# exporting Cheese_1544.wav
# exporting Cheese_1545.wav
# exporting Cheese_1546.wav
# exporting Cheese_1547.wav
# exporting Cheese_1548.wav
# exporting Cheese_1549.wav
# exporting Cheese_1550.wav
# exporting Cheese_1551.wav
# exporting Cheese_1552.wav
# exporting Cheese_1553.wav
# exporting Cheese_1554.wav
# exporting Cheese_1555.wav
# exporting Cheese_1556.wav
# exporting Cheese_1557.wav
# exporting Cheese_1558.wav
# exporting Cheese_1559.wav
# exporting Cheese_1560.wav
# exporting Cheese_1561.wav
# exporting Cheese_1562.wav
# exporting Cheese_1563.wav
# exporting Cheese_1564.wav
# exporting Cheese_1565.wav
# exporting Cheese_1566.wav
# exporting Cheese_1567.wav
# exporting Cheese_1568.wav
# exporting Cheese_1569.wav
# exporting Cheese_1570.wav
# exporting Cheese_1571.wav
# exporting Cheese_1572.wav
# exporting Cheese_1573.wav
# exporting Cheese_1574.wav
# exporting Cheese_1575.wav
# exporting Cheese_1576.wav
# exporting Cheese_1577.wav
# exporting Cheese_1578.wav
# exporting Cheese_1579.wav
# exporting Cheese_1580.wav
# exporting Cheese_1581.wav
# exporting Cheese_1582.wav
# exporting Cheese_1583.wav
# exporting Cheese_1584.wav
# exporting Cheese_1585.wav
# exporting Cheese_1586.wav
# exporting Cheese_1587.wav
# exporting Cheese_1588.wav
# exporting Cheese_1589.wav
# exporting Cheese_1590.wav
# exporting Cheese_1591.wav
# exporting Cheese_1592.wav
# exporting Cheese_1593.wav
# exporting Cheese_1594.wav
# exporting Cheese_1595.wav
# exporting Cheese_1596.wav
# exporting Cheese_1597.wav
# exporting Cheese_1598.wav
# exporting Cheese_1599.wav
# exporting Cheese_1600.wav
# exporting Cheese_1601.wav
# exporting Cheese_1602.wav
# exporting Cheese_1603.wav
# exporting Cheese_1604.wav
# exporting Cheese_1605.wav
# exporting Cheese_1606.wav
# exporting Cheese_1607.wav
# exporting Cheese_1608.wav
# exporting Cheese_1609.wav
# exporting Cheese_1610.wav
# exporting Cheese_1611.wav
# exporting Cheese_1612.wav
# exporting Cheese_1613.wav
# exporting Cheese_1614.wav
# exporting Cheese_1615.wav
# exporting Cheese_1616.wav
# exporting Cheese_1617.wav
# exporting Cheese_1618.wav
# exporting Cheese_1619.wav
# exporting Cheese_1620.wav
# exporting Cheese_1621.wav
# exporting Cheese_1622.wav
# exporting Cheese_1623.wav
# exporting Cheese_1624.wav
# exporting Cheese_1625.wav
# exporting Cheese_1626.wav
# exporting Cheese_1627.wav
# exporting Cheese_1628.wav
# exporting Cheese_1629.wav
# exporting Cheese_1630.wav
# exporting Cheese_1631.wav
# exporting Cheese_1632.wav
# exporting Cheese_1633.wav
# exporting Cheese_1634.wav
# exporting Cheese_1635.wav
# exporting Cheese_1636.wav
# exporting Cheese_1637.wav
# exporting Cheese_1638.wav
# exporting Cheese_1639.wav
# exporting Cheese_1640.wav
# exporting Cheese_1641.wav
# exporting Cheese_1642.wav
# exporting Cheese_1643.wav
# exporting Cheese_1644.wav
# exporting Cheese_1645.wav
# exporting Cheese_1646.wav
# exporting Cheese_1647.wav
# exporting Cheese_1648.wav
# exporting Cheese_1649.wav
# exporting Cheese_1650.wav
# exporting Cheese_1651.wav
# exporting Cheese_1652.wav
# exporting Cheese_1653.wav
# exporting Cheese_1654.wav
# exporting Cheese_1655.wav
# exporting Cheese_1656.wav
# exporting Cheese_1657.wav
# exporting Cheese_1658.wav
# exporting Cheese_1659.wav
# exporting Cheese_1660.wav
# exporting Cheese_1661.wav
# exporting Cheese_1662.wav
# exporting Cheese_1663.wav
# exporting Cheese_1664.wav
# exporting Cheese_1665.wav
# exporting Cheese_1666.wav
# exporting Cheese_1667.wav
# exporting Cheese_1668.wav
# exporting Cheese_1669.wav
# exporting Cheese_1670.wav
# exporting Cheese_1671.wav
# exporting Cheese_1672.wav
# exporting Cheese_1673.wav
# exporting Cheese_1674.wav
# exporting Cheese_1675.wav
# exporting Cheese_1676.wav
# exporting Cheese_1677.wav
# exporting Cheese_1678.wav
# exporting Cheese_1679.wav
# exporting Cheese_1680.wav
# exporting Cheese_1681.wav
# exporting Cheese_1682.wav
# exporting Cheese_1683.wav
# exporting Cheese_1684.wav
# exporting Cheese_1685.wav
# exporting Cheese_1686.wav
# exporting Cheese_1687.wav
# exporting Cheese_1688.wav
# exporting Cheese_1689.wav
# exporting Cheese_1690.wav
# exporting Cheese_1691.wav
# exporting Cheese_1692.wav
# exporting Cheese_1693.wav
# exporting Cheese_1694.wav
# exporting Cheese_1695.wav
# exporting Cheese_1696.wav
# exporting Cheese_1697.wav
# exporting Cheese_1698.wav
# exporting Cheese_1699.wav
# exporting Cheese_1700.wav
# exporting Cheese_1701.wav
# exporting Cheese_1702.wav
# exporting Cheese_1703.wav
# exporting Cheese_1704.wav
# exporting Cheese_1705.wav
# exporting Cheese_1706.wav
# exporting Cheese_1707.wav
# exporting Cheese_1708.wav
# exporting Cheese_1709.wav
# exporting Cheese_1710.wav
# exporting Cheese_1711.wav
# exporting Cheese_1712.wav
# exporting Cheese_1713.wav
# exporting Cheese_1714.wav
# exporting Cheese_1715.wav
# exporting Cheese_1716.wav
# exporting Cheese_1717.wav
# exporting Cheese_1718.wav
# exporting Cheese_1719.wav
# exporting Cheese_1720.wav
# exporting Cheese_1721.wav
# exporting Cheese_1722.wav
# exporting Cheese_1723.wav
# exporting Cheese_1724.wav
# exporting Cheese_1725.wav
# exporting Cheese_1726.wav
# exporting Cheese_1727.wav
# exporting Cheese_1728.wav
# exporting Cheese_1729.wav
# exporting Cheese_1730.wav
# exporting Cheese_1731.wav
# exporting Cheese_1732.wav
# exporting Cheese_1733.wav
# exporting Cheese_1734.wav
# exporting Cheese_1735.wav
# exporting Cheese_1736.wav
# exporting Cheese_1737.wav
# exporting Cheese_1738.wav
# exporting Cheese_1739.wav
# exporting Cheese_1740.wav
# exporting Cheese_1741.wav
# exporting Cheese_1742.wav
# exporting Cheese_1743.wav
# exporting Cheese_1744.wav
# exporting Cheese_1745.wav
# exporting Cheese_1746.wav
# exporting Cheese_1747.wav
# exporting Cheese_1748.wav
# exporting Cheese_1749.wav
# exporting Cheese_1750.wav
# exporting Cheese_1751.wav
# exporting Cheese_1752.wav
# exporting Cheese_1753.wav
# exporting Cheese_1754.wav
# exporting Cheese_1755.wav
# exporting Cheese_1756.wav
# exporting Cheese_1757.wav
# exporting Cheese_1758.wav
# exporting Cheese_1759.wav
# exporting Cheese_1760.wav
# exporting Cheese_1761.wav
# exporting Cheese_1762.wav
# exporting Cheese_1763.wav
# exporting Cheese_1764.wav
# exporting Cheese_1765.wav
# exporting Cheese_1766.wav
# exporting Cheese_1767.wav
# exporting Cheese_1768.wav
# exporting Cheese_1769.wav
# exporting Cheese_1770.wav
# exporting Cheese_1771.wav
# exporting Cheese_1772.wav
# exporting Cheese_1773.wav
# exporting Cheese_1774.wav
# exporting Cheese_1775.wav
# exporting Cheese_1776.wav
# exporting Cheese_1777.wav
# exporting Cheese_1778.wav
# exporting Cheese_1779.wav
# exporting Cheese_1780.wav
# exporting Cheese_1781.wav
# exporting Cheese_1782.wav
# exporting Cheese_1783.wav
# exporting Cheese_1784.wav
# exporting Cheese_1785.wav
# exporting Cheese_1786.wav
# exporting Cheese_1787.wav
# exporting Cheese_1788.wav
# exporting Cheese_1789.wav
# exporting Cheese_1790.wav
# exporting Cheese_1791.wav
# exporting Cheese_1792.wav
# exporting Cheese_1793.wav
# exporting Cheese_1794.wav
# exporting Cheese_1795.wav
# exporting Cheese_1796.wav
# exporting Cheese_1797.wav
# exporting Cheese_1798.wav
# exporting Cheese_1799.wav
# exporting Cheese_1800.wav
# exporting Cheese_1801.wav
# exporting Cheese_1802.wav
# exporting Cheese_1803.wav
# exporting Cheese_1804.wav
# exporting Cheese_1805.wav
# exporting Cheese_1806.wav
# exporting Cheese_1807.wav
# exporting Cheese_1808.wav
# exporting Cheese_1809.wav
# exporting Cheese_1810.wav
# exporting Cheese_1811.wav
# exporting Cheese_1812.wav
# exporting Cheese_1813.wav
# exporting Cheese_1814.wav
# exporting Cheese_1815.wav
# exporting Cheese_1816.wav
# exporting Cheese_1817.wav
# exporting Cheese_1818.wav
# exporting Cheese_1819.wav
# exporting Cheese_1820.wav
# exporting Cheese_1821.wav
# exporting Cheese_1822.wav
# exporting Cheese_1823.wav
# exporting Cheese_1824.wav
# exporting Cheese_1825.wav
# exporting Cheese_1826.wav
# exporting Cheese_1827.wav
# exporting Cheese_1828.wav
# exporting Cheese_1829.wav
# exporting Cheese_1830.wav
# exporting Cheese_1831.wav
# exporting Cheese_1832.wav
# exporting Cheese_1833.wav
# exporting Cheese_1834.wav
# exporting Cheese_1835.wav
# exporting Cheese_1836.wav
# exporting Cheese_1837.wav
# exporting Cheese_1838.wav
# exporting Cheese_1839.wav
# exporting Cheese_1840.wav
# exporting Cheese_1841.wav
# exporting Cheese_1842.wav
# exporting Cheese_1843.wav
# exporting Cheese_1844.wav
# exporting Cheese_1845.wav
# exporting Cheese_1846.wav
# exporting Cheese_1847.wav
# exporting Cheese_1848.wav
# exporting Cheese_1849.wav
# exporting Cheese_1850.wav
# exporting Cheese_1851.wav
# exporting Cheese_1852.wav
# exporting Cheese_1853.wav
# exporting Cheese_1854.wav
# exporting Cheese_1855.wav
# exporting Cheese_1856.wav
# exporting Cheese_1857.wav
# exporting Cheese_1858.wav
# exporting Cheese_1859.wav
# exporting Cheese_1860.wav
# exporting Cheese_1861.wav
# exporting Cheese_1862.wav
# exporting Cheese_1863.wav
# exporting Cheese_1864.wav
# exporting Cheese_1865.wav
# exporting Cheese_1866.wav
# exporting Cheese_1867.wav
# exporting Cheese_1868.wav
# exporting Cheese_1869.wav
# exporting Cheese_1870.wav
# exporting Cheese_1871.wav
# exporting Cheese_1872.wav
# exporting Cheese_1873.wav
# exporting Cheese_1874.wav
# exporting Cheese_1875.wav
# exporting Cheese_1876.wav
# exporting Cheese_1877.wav
# exporting Cheese_1878.wav
# exporting Cheese_1879.wav
# exporting Cheese_1880.wav
# exporting Cheese_1881.wav
# exporting Cheese_1882.wav
# exporting Cheese_1883.wav
# exporting Cheese_1884.wav
# exporting Cheese_1885.wav
# exporting Cheese_1886.wav
# exporting Cheese_1887.wav
# exporting Cheese_1888.wav
# exporting Cheese_1889.wav
# exporting Cheese_1890.wav
# exporting Cheese_1891.wav
# exporting Cheese_1892.wav
# exporting Cheese_1893.wav
# exporting Cheese_1894.wav
# exporting Cheese_1895.wav
# exporting Cheese_1896.wav
# exporting Cheese_1897.wav
# exporting Cheese_1898.wav
# exporting Cheese_1899.wav
# exporting Cheese_1900.wav
# exporting Cheese_1901.wav
# exporting Cheese_1902.wav
# exporting Cheese_1903.wav
# exporting Cheese_1904.wav
# exporting Cheese_1905.wav
# exporting Cheese_1906.wav
# exporting Cheese_1907.wav
# exporting Cheese_1908.wav
# exporting Cheese_1909.wav
# exporting Cheese_1910.wav
# exporting Cheese_1911.wav
# exporting Cheese_1912.wav
# exporting Cheese_1913.wav
# exporting Cheese_1914.wav
# exporting Cheese_1915.wav
# exporting Cheese_1916.wav
# exporting Cheese_1917.wav
# exporting Cheese_1918.wav
# exporting Cheese_1919.wav
# exporting Cheese_1920.wav
# exporting Cheese_1921.wav
# exporting Cheese_1922.wav
# exporting Cheese_1923.wav
# exporting Cheese_1924.wav
# exporting Cheese_1925.wav
# exporting Cheese_1926.wav
# exporting Cheese_1927.wav
# exporting Cheese_1928.wav
# exporting Cheese_1929.wav
# exporting Cheese_1930.wav
# exporting Cheese_1931.wav
# exporting Cheese_1932.wav
# exporting Cheese_1933.wav
# exporting Cheese_1934.wav
# exporting Cheese_1935.wav
# exporting Cheese_1936.wav
# exporting Cheese_1937.wav
# exporting Cheese_1938.wav
# exporting Cheese_1939.wav
# exporting Cheese_1940.wav
# exporting Cheese_1941.wav
# exporting Cheese_1942.wav
# exporting Cheese_1943.wav
# exporting Cheese_1944.wav
# exporting Cheese_1945.wav
# exporting Cheese_1946.wav
# exporting Cheese_1947.wav
# exporting Cheese_1948.wav
# exporting Cheese_1949.wav
# exporting Cheese_1950.wav
# exporting Cheese_1951.wav
# exporting Cheese_1952.wav
# exporting Cheese_1953.wav
# exporting Cheese_1954.wav
# exporting Cheese_1955.wav
# exporting Cheese_1956.wav
# exporting Cheese_1957.wav
# exporting Cheese_1958.wav
# exporting Cheese_1959.wav
# exporting Cheese_1960.wav
# exporting Cheese_1961.wav
# exporting Cheese_1962.wav
# exporting Cheese_1963.wav
# exporting Cheese_1964.wav
# exporting Cheese_1965.wav
# exporting Cheese_1966.wav
# exporting Cheese_1967.wav
# exporting Cheese_1968.wav
# exporting Cheese_1969.wav
# exporting Cheese_1970.wav
# exporting Cheese_1971.wav
# exporting Cheese_1972.wav
# exporting Cheese_1973.wav
# exporting Cheese_1974.wav
# exporting Cheese_1975.wav
# exporting Cheese_1976.wav
# exporting Cheese_1977.wav
# exporting Cheese_1978.wav
# exporting Cheese_1979.wav
# exporting Cheese_1980.wav
# exporting Cheese_1981.wav
# exporting Cheese_1982.wav
# exporting Cheese_1983.wav
# exporting Cheese_1984.wav
# exporting Cheese_1985.wav
# exporting Cheese_1986.wav
# exporting Cheese_1987.wav
# exporting Cheese_1988.wav
# exporting Cheese_1989.wav
# exporting Cheese_1990.wav
# exporting Cheese_1991.wav
# exporting Cheese_1992.wav
# exporting Cheese_1993.wav
# exporting Cheese_1994.wav
# exporting Cheese_1995.wav
# exporting Cheese_1996.wav
# exporting Cheese_1997.wav
# exporting Cheese_1998.wav
# exporting Cheese_1999.wav
# exporting Cheese_2000.wav
# exporting Cheese_2001.wav
# exporting Cheese_2002.wav
# exporting Cheese_2003.wav
# exporting Cheese_2004.wav
# exporting Cheese_2005.wav
# exporting Cheese_2006.wav
# exporting Cheese_2007.wav
# exporting Cheese_2008.wav
# exporting Cheese_2009.wav
# exporting Cheese_2010.wav
# exporting Cheese_2011.wav
# exporting Cheese_2012.wav
# exporting Cheese_2013.wav
# exporting Cheese_2014.wav
# exporting Cheese_2015.wav
# exporting Cheese_2016.wav
# exporting Cheese_2017.wav
# exporting Cheese_2018.wav
# exporting Cheese_2019.wav
# exporting Cheese_2020.wav
# exporting Cheese_2021.wav
# exporting Cheese_2022.wav
# exporting Cheese_2023.wav
# exporting Cheese_2024.wav
# exporting Cheese_2025.wav
# exporting Cheese_2026.wav
# exporting Cheese_2027.wav
# exporting Cheese_2028.wav
# exporting Cheese_2029.wav
# exporting Cheese_2030.wav
# exporting Cheese_2031.wav
# exporting Cheese_2032.wav
# exporting Cheese_2033.wav
# exporting Cheese_2034.wav
# exporting Cheese_2035.wav
# exporting Cheese_2036.wav
# exporting Cheese_2037.wav
# exporting Cheese_2038.wav
# exporting Cheese_2039.wav
# exporting Cheese_2040.wav
# exporting Cheese_2041.wav
# exporting Cheese_2042.wav
# exporting Cheese_2043.wav
# exporting Cheese_2044.wav
# exporting Cheese_2045.wav
# exporting Cheese_2046.wav
# exporting Cheese_2047.wav
# exporting Cheese_2048.wav
# exporting Cheese_2049.wav
# exporting Cheese_2050.wav
# exporting Cheese_2051.wav
# exporting Cheese_2052.wav
# exporting Cheese_2053.wav
# exporting Cheese_2054.wav
# exporting Cheese_2055.wav
# exporting Cheese_2056.wav
# exporting Cheese_2057.wav
# exporting Cheese_2058.wav
# exporting Cheese_2059.wav
# exporting Cheese_2060.wav
# exporting Cheese_2061.wav
# exporting Cheese_2062.wav
# exporting Cheese_2063.wav
# exporting Cheese_2064.wav
# exporting Cheese_2065.wav
# exporting Cheese_2066.wav
# exporting Cheese_2067.wav
# exporting Cheese_2068.wav
# exporting Cheese_2069.wav
# exporting Cheese_2070.wav
# exporting Cheese_2071.wav
# exporting Cheese_2072.wav
# exporting Cheese_2073.wav
# exporting Cheese_2074.wav
# exporting Cheese_2075.wav
# exporting Cheese_2076.wav
# exporting Cheese_2077.wav
# exporting Cheese_2078.wav
# exporting Cheese_2079.wav
# exporting Cheese_2080.wav
# exporting Cheese_2081.wav
# exporting Cheese_2082.wav
# exporting Cheese_2083.wav
# exporting Cheese_2084.wav
# exporting Cheese_2085.wav
# exporting Cheese_2086.wav
# exporting Cheese_2087.wav
# exporting Cheese_2088.wav
# exporting Cheese_2089.wav
# exporting Cheese_2090.wav
# exporting Cheese_2091.wav
# exporting Cheese_2092.wav
# exporting Cheese_2093.wav
# exporting Cheese_2094.wav
# exporting Cheese_2095.wav
# exporting Cheese_2096.wav
# exporting Cheese_2097.wav
# exporting Cheese_2098.wav
# exporting Cheese_2099.wav
# exporting Cheese_2100.wav
# exporting Cheese_2101.wav
# exporting Cheese_2102.wav
# exporting Cheese_2103.wav
# exporting Cheese_2104.wav
# exporting Cheese_2105.wav
# exporting Cheese_2106.wav
# exporting Cheese_2107.wav
# exporting Cheese_2108.wav
# exporting Cheese_2109.wav
# exporting Cheese_2110.wav
# exporting Cheese_2111.wav
# exporting Cheese_2112.wav
# exporting Cheese_2113.wav
# exporting Cheese_2114.wav
# exporting Cheese_2115.wav
# exporting Cheese_2116.wav
# exporting Cheese_2117.wav
# exporting Cheese_2118.wav
# exporting Cheese_2119.wav
# exporting Cheese_2120.wav
# exporting Cheese_2121.wav
# exporting Cheese_2122.wav
# exporting Cheese_2123.wav
# exporting Cheese_2124.wav
# exporting Cheese_2125.wav
# exporting Cheese_2126.wav
# exporting Cheese_2127.wav
# exporting Cheese_2128.wav
# exporting Cheese_2129.wav
# exporting Cheese_2130.wav
# exporting Cheese_2131.wav
# exporting Cheese_2132.wav
# exporting Cheese_2133.wav
# exporting Cheese_2134.wav
# exporting Cheese_2135.wav
# exporting Cheese_2136.wav
# exporting Cheese_2137.wav
# exporting Cheese_2138.wav
# exporting Cheese_2139.wav
# exporting Cheese_2140.wav
# exporting Cheese_2141.wav
# exporting Cheese_2142.wav
# exporting Cheese_2143.wav
# exporting Cheese_2144.wav
# exporting Cheese_2145.wav
# exporting Cheese_2146.wav
# exporting Cheese_2147.wav
# exporting Cheese_2148.wav
# exporting Cheese_2149.wav
# exporting Cheese_2150.wav
# exporting Cheese_2151.wav
# exporting Cheese_2152.wav
# exporting Cheese_2153.wav
# exporting Cheese_2154.wav
# exporting Cheese_2155.wav
# exporting Cheese_2156.wav
# exporting Cheese_2157.wav
# exporting Cheese_2158.wav
# exporting Cheese_2159.wav
# exporting Cheese_2160.wav
# exporting Cheese_2161.wav
# exporting Cheese_2162.wav
# exporting Cheese_2163.wav
# exporting Cheese_2164.wav
# exporting Cheese_2165.wav
# exporting Cheese_2166.wav
# exporting Cheese_2167.wav
# exporting Cheese_2168.wav
# exporting Cheese_2169.wav
# exporting Cheese_2170.wav
# exporting Cheese_2171.wav
# exporting Cheese_2172.wav
# exporting Cheese_2173.wav
# exporting Cheese_2174.wav
# exporting Cheese_2175.wav
# exporting Cheese_2176.wav
# exporting Cheese_2177.wav
# exporting Cheese_2178.wav
# exporting Cheese_2179.wav
# exporting Cheese_2180.wav
# exporting Cheese_2181.wav
# exporting Cheese_2182.wav
# exporting Cheese_2183.wav
# exporting Cheese_2184.wav
# exporting Cheese_2185.wav
# exporting Cheese_2186.wav
# exporting Cheese_2187.wav
# exporting Cheese_2188.wav
# exporting Cheese_2189.wav
# exporting Cheese_2190.wav
# exporting Cheese_2191.wav
# exporting Cheese_2192.wav
# exporting Cheese_2193.wav
# exporting Cheese_2194.wav
# exporting Cheese_2195.wav
# exporting Cheese_2196.wav
# exporting Cheese_2197.wav
# exporting Cheese_2198.wav
# exporting Cheese_2199.wav
# exporting Cheese_2200.wav
# exporting Cheese_2201.wav
# exporting Cheese_2202.wav
# exporting Cheese_2203.wav
# exporting Cheese_2204.wav
# exporting Cheese_2205.wav
# exporting Cheese_2206.wav
# exporting Cheese_2207.wav
# exporting Cheese_2208.wav
# exporting Cheese_2209.wav
# exporting Cheese_2210.wav
# exporting Cheese_2211.wav
# exporting Cheese_2212.wav
# exporting Cheese_2213.wav
# exporting Cheese_2214.wav
# exporting Cheese_2215.wav
# exporting Cheese_2216.wav
# exporting Cheese_2217.wav
# exporting Cheese_2218.wav
# exporting Cheese_2219.wav
# exporting Cheese_2220.wav
# exporting Cheese_2221.wav
# exporting Cheese_2222.wav
# exporting Cheese_2223.wav
# exporting Cheese_2224.wav
# exporting Cheese_2225.wav
# exporting Cheese_2226.wav
# exporting Cheese_2227.wav
# exporting Cheese_2228.wav
# exporting Cheese_2229.wav
# exporting Cheese_2230.wav
# exporting Cheese_2231.wav
# exporting Cheese_2232.wav
# exporting Cheese_2233.wav
# exporting Cheese_2234.wav
# exporting Cheese_2235.wav
# exporting Cheese_2236.wav
# exporting Cheese_2237.wav
# exporting Cheese_2238.wav
# exporting Cheese_2239.wav
# exporting Cheese_2240.wav
# exporting Cheese_2241.wav
# exporting Cheese_2242.wav
# exporting Cheese_2243.wav
# exporting Cheese_2244.wav
# exporting Cheese_2245.wav
# exporting Cheese_2246.wav
# exporting Cheese_2247.wav
# exporting Cheese_2248.wav
# exporting Cheese_2249.wav
# exporting Cheese_2250.wav
# exporting Cheese_2251.wav
# exporting Cheese_2252.wav
# exporting Cheese_2253.wav
# exporting Cheese_2254.wav
# exporting Cheese_2255.wav
# exporting Cheese_2256.wav
# exporting Cheese_2257.wav
# exporting Cheese_2258.wav
# exporting Cheese_2259.wav
# exporting Cheese_2260.wav
# exporting Cheese_2261.wav
# exporting Cheese_2262.wav
# exporting Cheese_2263.wav
# exporting Cheese_2264.wav
# exporting Cheese_2265.wav
# exporting Cheese_2266.wav
# exporting Cheese_2267.wav
# exporting Cheese_2268.wav
# exporting Cheese_2269.wav
# exporting Cheese_2270.wav
# exporting Cheese_2271.wav
# exporting Cheese_2272.wav
# exporting Cheese_2273.wav
# exporting Cheese_2274.wav
# exporting Cheese_2275.wav
# exporting Cheese_2276.wav
# exporting Cheese_2277.wav
# exporting Cheese_2278.wav
# exporting Cheese_2279.wav
# exporting Cheese_2280.wav
# exporting Cheese_2281.wav
# exporting Cheese_2282.wav
# exporting Cheese_2283.wav
# exporting Cheese_2284.wav
# exporting Cheese_2285.wav
# exporting Cheese_2286.wav
# exporting Cheese_2287.wav
# exporting Cheese_2288.wav
# exporting Cheese_2289.wav
# exporting Cheese_2290.wav
# exporting Cheese_2291.wav
# exporting Cheese_2292.wav
# exporting Cheese_2293.wav
# exporting Cheese_2294.wav
# exporting Cheese_2295.wav
# exporting Cheese_2296.wav
# exporting Cheese_2297.wav
# exporting Cheese_2298.wav
# exporting Cheese_2299.wav
# exporting Cheese_2300.wav
# exporting Cheese_2301.wav
# exporting Cheese_2302.wav
# exporting Cheese_2303.wav
# exporting Cheese_2304.wav
# exporting Cheese_2305.wav
# exporting Cheese_2306.wav
# exporting Cheese_2307.wav
# exporting Cheese_2308.wav
# exporting Cheese_2309.wav
# exporting Cheese_2310.wav
# exporting Cheese_2311.wav
# exporting Cheese_2312.wav
# exporting Cheese_2313.wav
# exporting Cheese_2314.wav
# exporting Cheese_2315.wav
# exporting Cheese_2316.wav
# exporting Cheese_2317.wav
# exporting Cheese_2318.wav
# exporting Cheese_2319.wav
# exporting Cheese_2320.wav
# exporting Cheese_2321.wav
# exporting Cheese_2322.wav
# exporting Cheese_2323.wav
# exporting Cheese_2324.wav
# exporting Cheese_2325.wav
# exporting Cheese_2326.wav
# exporting Cheese_2327.wav
# exporting Cheese_2328.wav
# exporting Cheese_2329.wav
# exporting Cheese_2330.wav
# exporting Cheese_2331.wav
# exporting Cheese_2332.wav
# exporting Cheese_2333.wav
# exporting Cheese_2334.wav
# exporting Cheese_2335.wav
# exporting Cheese_2336.wav
# exporting Cheese_2337.wav
# exporting Cheese_2338.wav
# exporting Cheese_2339.wav
# exporting Cheese_2340.wav
# exporting Cheese_2341.wav
# exporting Cheese_2342.wav
# exporting Cheese_2343.wav
# exporting Cheese_2344.wav
# exporting Cheese_2345.wav
# exporting Cheese_2346.wav
# exporting Cheese_2347.wav
# exporting Cheese_2348.wav
# exporting Cheese_2349.wav
# exporting Cheese_2350.wav
# exporting Cheese_2351.wav
# exporting Cheese_2352.wav
# exporting Cheese_2353.wav
# exporting Cheese_2354.wav
# exporting Cheese_2355.wav
# exporting Cheese_2356.wav
# exporting Cheese_2357.wav
# exporting Cheese_2358.wav
# exporting Cheese_2359.wav
# exporting Cheese_2360.wav
# exporting Cheese_2361.wav
# exporting Cheese_2362.wav
# exporting Cheese_2363.wav
# exporting Cheese_2364.wav
# exporting Cheese_2365.wav
# exporting Cheese_2366.wav
# exporting Cheese_2367.wav
# exporting Cheese_2368.wav
# exporting Cheese_2369.wav
# exporting Cheese_2370.wav
# exporting Cheese_2371.wav
# exporting Cheese_2372.wav
# exporting Cheese_2373.wav
# exporting Cheese_2374.wav
# exporting Cheese_2375.wav
# exporting Cheese_2376.wav
# exporting Cheese_2377.wav
# exporting Cheese_2378.wav
# exporting Cheese_2379.wav
# exporting Cheese_2380.wav
# exporting Cheese_2381.wav
# exporting Cheese_2382.wav
# exporting Cheese_2383.wav
# exporting Cheese_2384.wav
# exporting Cheese_2385.wav
# exporting Cheese_2386.wav
# exporting Cheese_2387.wav
# exporting Cheese_2388.wav
# exporting Cheese_2389.wav
# exporting Cheese_2390.wav
# exporting Cheese_2391.wav
# exporting Cheese_2392.wav
# exporting Cheese_2393.wav
# exporting Cheese_2394.wav
# exporting Cheese_2395.wav
# exporting Cheese_2396.wav
# exporting Cheese_2397.wav
# exporting Cheese_2398.wav
# exporting Cheese_2399.wav
# exporting Cheese_2400.wav
# exporting Cheese_2401.wav
# exporting Cheese_2402.wav
# exporting Cheese_2403.wav
# exporting Cheese_2404.wav
# exporting Cheese_2405.wav
# exporting Cheese_2406.wav
# exporting Cheese_2407.wav
# exporting Cheese_2408.wav
# exporting Cheese_2409.wav
# exporting Cheese_2410.wav
# exporting Cheese_2411.wav
# exporting Cheese_2412.wav
# exporting Cheese_2413.wav
# exporting Cheese_2414.wav
# exporting Cheese_2415.wav
# exporting Cheese_2416.wav
# exporting Cheese_2417.wav
# exporting Cheese_2418.wav
# exporting Cheese_2419.wav
# exporting Cheese_2420.wav
# exporting Cheese_2421.wav
# exporting Cheese_2422.wav
# exporting Cheese_2423.wav
# exporting Cheese_2424.wav
# exporting Cheese_2425.wav
# exporting Cheese_2426.wav
# exporting Cheese_2427.wav
# exporting Cheese_2428.wav
# exporting Cheese_2429.wav
# exporting Cheese_2430.wav
# exporting Cheese_2431.wav
# exporting Cheese_2432.wav
# exporting Cheese_2433.wav
# exporting Cheese_2434.wav
# exporting Cheese_2435.wav
# exporting Cheese_2436.wav
# exporting Cheese_2437.wav
# exporting Cheese_2438.wav
# exporting Cheese_2439.wav
# exporting Cheese_2440.wav
# exporting Cheese_2441.wav
# exporting Cheese_2442.wav
# exporting Cheese_2443.wav
# exporting Cheese_2444.wav
# exporting Cheese_2445.wav
# exporting Cheese_2446.wav
# exporting Cheese_2447.wav
# exporting Cheese_2448.wav
# exporting Cheese_2449.wav
# exporting Cheese_2450.wav
# exporting Cheese_2451.wav
# exporting Cheese_2452.wav
# exporting Cheese_2453.wav
# exporting Cheese_2454.wav
# exporting Cheese_2455.wav
# exporting Cheese_2456.wav
# exporting Cheese_2457.wav
# exporting Cheese_2458.wav
# exporting Cheese_2459.wav
# exporting Cheese_2460.wav
# exporting Cheese_2461.wav
# exporting Cheese_2462.wav
# exporting Cheese_2463.wav
# exporting Cheese_2464.wav
# exporting Cheese_2465.wav
# exporting Cheese_2466.wav
# exporting Cheese_2467.wav
# exporting Cheese_2468.wav
# exporting Cheese_2469.wav
# exporting Cheese_2470.wav
# exporting Cheese_2471.wav
# exporting Cheese_2472.wav
# exporting Cheese_2473.wav
# exporting Cheese_2474.wav
# exporting Cheese_2475.wav
# exporting Cheese_2476.wav
# exporting Cheese_2477.wav
# exporting Cheese_2478.wav
# exporting Cheese_2479.wav
# exporting Cheese_2480.wav
# exporting Cheese_2481.wav
# exporting Cheese_2482.wav
# exporting Cheese_2483.wav
# exporting Cheese_2484.wav
# exporting Cheese_2485.wav
# exporting Cheese_2486.wav
# exporting Cheese_2487.wav
# exporting Cheese_2488.wav
# exporting Cheese_2489.wav
# Exporting finished. Total number of chunks is 10013

# %%
tot_number_of_chunks == o_b + n_b + all_c + e # check point
# Out:
# True

# %%
print(o_b, n_b, c, e) # they should be close to each other to have balanced dataset
# Out:
# 2507 2509 2490 2507

# %% [markdown]
# # Extract MFCCs and save as npz

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display

# %%
chunks_path = "sliding_chunks"
filenames = sorted([f for f in os.listdir(chunks_path) if f.endswith('.wav')])

# %%
# important
len(filenames) # check number of chunks, wait until it reads all of the chunks
# Out:
# 10013

# %%
# split data into training, validation and test randomly
import random
shuffle = True
if shuffle: 
  random.seed(13)
  random.shuffle(filenames)

total = len(filenames)
list_train = filenames[0:int(total*0.8)]
list_valid = filenames[int(total*0.8):int(total*0.9)]
list_test = filenames[int(total*0.9)::]

# %%
dict_classes = {"Cheese":0, "Empty":1, "NonorganicButter":2, "OrganicButter":3}

# %% [markdown]
# ### Obtain MFCCs

# %%
def extract_features_MFCCs(filename):
  """ This function takes the path for an audio file as a string, 
  loads it, and returns the MFCC of the audio. """
  
  file_path = os.path.join(chunks_path, filename)
  chunk, sample_rate = librosa.load(file_path, sr=None, res_type="kaiser_fast") 
  mfccs = librosa.feature.mfcc(y=chunk, sr=sample_rate, n_mfcc=40)
    
  return mfccs.T

# %%
def create_array_MFCCs(filenames):
    classes = []
    X_spect = np.empty((0, 173, 40)) # [1] is defined according to the length of the chunk
    count = 0
    # code skips records in case of errors
    for filename in filenames:
        try:
            count += 1    
            a_class = filename.split("_")[0]
            spect = extract_features_MFCCs(filename)

            # normalize for small shape differences
            spect = spect[:173, :] # according to the lengths of the chunks
            X_spect = np.append(X_spect, [spect], axis=0)
            classes.append(dict_classes[a_class])
            
            if count % 100 == 0:
                print("Currently processing:", count)
        except:
            print("Couldn't process:", count)
            continue
    y_arr = np.array(classes)
    return X_spect, y_arr

# %%
# %mkdir npz_files
# %cd /npz_files
# Out:
# /content/drive/My Drive/Data Science Projects/Peynir/Peynir-Paper/npz_files

# %%
X_test, y_test = create_array_MFCCs(list_test)
print(X_test.shape, y_test.shape)
np.savez("shuffled_test_arr_MFCCs", X_test, y_test)
# Out:
# Currently processing: 100
# Currently processing: 200
# Currently processing: 300
# Currently processing: 400
# Currently processing: 500
# Currently processing: 600
# Currently processing: 700
# Currently processing: 800
# Currently processing: 900
# Currently processing: 1000
# (1002, 173, 40) (1002,)

# %%
X_valid, y_valid = create_array_MFCCs(list_valid)
print(X_valid.shape, y_valid.shape)
np.savez("shuffled_valid_arr_MFCCs", X_valid, y_valid)
# Out:
# Currently processing: 100
# Currently processing: 200
# Currently processing: 300
# Currently processing: 400
# Currently processing: 500
# Currently processing: 600
# Currently processing: 700
# Currently processing: 800
# Currently processing: 900
# Currently processing: 1000
# (1001, 173, 40) (1001,)

# %%
X_train, y_train = create_array_MFCCs(list_train)
print(X_train.shape, y_train.shape)
np.savez("shuffled_train_arr_MFCCs", X_train, y_train)
# Out:
# Currently processing: 100
# Currently processing: 200
# Currently processing: 300
# Currently processing: 400
# Currently processing: 500
# Currently processing: 600
# Currently processing: 700
# Currently processing: 800
# Currently processing: 900
# Currently processing: 1000
# Currently processing: 1100
# Currently processing: 1200
# Currently processing: 1300
# Currently processing: 1400
# Currently processing: 1500
# Currently processing: 1600
# Currently processing: 1700
# Currently processing: 1800
# Currently processing: 1900
# Currently processing: 2000
# Currently processing: 2100
# Currently processing: 2200
# Currently processing: 2300
# Currently processing: 2400
# Currently processing: 2500
# Currently processing: 2600
# Currently processing: 2700
# Currently processing: 2800
# Currently processing: 2900
# Currently processing: 3000
# Currently processing: 3100
# Currently processing: 3200
# Currently processing: 3300
# Currently processing: 3400
# Currently processing: 3500
# Currently processing: 3600
# Currently processing: 3700
# Currently processing: 3800
# Currently processing: 3900
# Currently processing: 4000
# Currently processing: 4100
# Currently processing: 4200
# Currently processing: 4300
# Currently processing: 4400
# Currently processing: 4500
# Currently processing: 4600
# Currently processing: 4700
# Currently processing: 4800
# Currently processing: 4900
# Currently processing: 5000
# Currently processing: 5100
# Currently processing: 5200
# Currently processing: 5300
# Currently processing: 5400
# Currently processing: 5500
# Currently processing: 5600
# Currently processing: 5700
# Currently processing: 5800
# Currently processing: 5900
# Currently processing: 6000
# Currently processing: 6100
# Currently processing: 6200
# Currently processing: 6300
# Currently processing: 6400
# Currently processing: 6500
# Currently processing: 6600
# Currently processing: 6700
# Currently processing: 6800
# Currently processing: 6900
# Currently processing: 7000
# Currently processing: 7100
# Currently processing: 7200
# Currently processing: 7300
# Currently processing: 7400
# Currently processing: 7500
# Currently processing: 7600
# Currently processing: 7700
# Currently processing: 7800
# Currently processing: 7900
# Currently processing: 8000
# (8010, 173, 40) (8010,)
